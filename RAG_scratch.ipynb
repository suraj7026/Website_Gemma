# %%
# !pip install langchain_community tiktoken langchain-openai langchainhub chromadb langchain langsmith langchain-nomic langgraph tavily-python gpt4all firecrawl-py
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.2/44.2 kB 4.9 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Installing backend dependencies ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#   Using cached pytest-8.2.1-py3-none-any.whl.metadata (7.6 kB)
# ...
#   Using cached pandas-2.2.2-cp310-cp310-macosx_11_0_arm64.whl.metadata (19 kB)
# ...
#   Using cached pyarrow-16.1.0-cp310-cp310-macosx_11_0_arm64.whl.metadata (3.0 kB)
# ...
#   Using cached pillow-10.3.0-cp310-cp310-macosx_11_0_arm64.whl.metadata (9.2 kB)
# ...
#   Using cached iniconfig-2.0.0-py3-none-any.whl.metadata (2.6 kB)
# ...
#   Using cached pluggy-1.5.0-py3-none-any.whl.metadata (4.8 kB)
# ...
#   Using cached pytz-2024.1-py2.py3-none-any.whl.metadata (22 kB)
# ...
#   Using cached tzdata-2024.1-py2.py3-none-any.whl.metadata (1.4 kB)
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 87.8/87.8 kB 6.8 MB/s eta 0:00:00
# ...

# %%
import os
os.environ['LANGCHAIN_TRACING_V2'] = 'true'
os.environ['LANGCHAIN_API_KEY'] = ''
os.environ['LANGCHAIN_ENDPOINT'] = 'https://api.smith.langchain.com'

os.environ['OPENAI_API_KEY'] = ''
os.environ['ANTHROPIC_API_KEY'] = ""

# %%
# Local LLM 
local_llm = 'llama3'

# %%
from lanchain.text_splitter import RecursiveCharacterTextSplitter
